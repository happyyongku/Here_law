# %%
import pandas as pd

# 파일 경로를 수정한 후 파일 불러오기
df_raw = pd.read_csv("/home/ubuntu/kbg_workspace/S11P21B109/datas/case_datas/train_5.csv")  # 여기에 정확한 파일 경로 입력

print(df_raw.head())
# Out:
#    판례정보일련번호  사건명       사건번호      선고일자  선고   법원명 사건종류명   판결유형  \
# 0     86640  NaN  4294민재항12  19610122  선고   대법원    민사     판결
# 1    190234  NaN   2000노709  20000704  선고  서울고법    형사  판결：확정
# 2    104477  NaN   86다카2634  19880927  선고   대법원    민사     판결
# 3    190250  NaN      99재노6  20010227   자  부산고법    형사  결정：확정
# 4    105119  NaN   86다카1147  19890425  선고   대법원    민사     판결
#
#                                                 판시사항  \
# 0           판사의 서명만 있고 날인이 없는 경매기일 조서와 경락허가결정 선고의 효력
# 1  [1]공모공동정범에 있어서 공모관계의 성립 요건 및 공동정범의 성립 요건 [2]집회...
# 2  가. 민법 제555조의 규정취지와 증여의사의 서면에의 표시정도 나. 부동산을 매수하...
# 3  [1] 형사소송법 제420조 제2호 소정의 '원판결의 증거된 증언'의 의미 [2]위...
# 4  가. 계약의 합의해제와 채무불이행으로 인한 손해배상청구 나. 건축공사도급계약이 중도...
#
#                                                 판결요지  \
# 0  경락허가결정선고의 방식의 적부는 조서에 의하여서만 증명할 수 있는바 경락기일조서에 ...
# 1  [1]공모공동정범의 경우에 공모는 2인 이상이 공모하여 범죄에 공동가공하여 범죄를 ...
# 2  가. 민법 제555조가 서면에 의하지 아니한 증여는 해제할 수 있다고 한 것은 증여...
# 3  [1] 형사소송법 제420조 제2호 소정의 재심사유에 해당하려면 원판결의 증거된 증...
# ...
